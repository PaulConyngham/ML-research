# %%
 
ACCESS_TOKEN    = "726947147493478400-3GtEFJZ89BtsWHOdoz52ALW0YJgXNWz"
ACCESS_SECRET   = "NJ6ImTcy2tKFwolgWwgRj9Pmhs6YkmE96MY47JiHAYMOf"
Consumer_Key    = "wqbHWrNG5nJ7GBkVlCI54nEMG"
Consumer_SECRET = "pRSX9ewn1uD5SL4VEhDMjKEAlYiATTV4th1IrCDkY3IWD6lwxj"

twitter = Twython(Consumer_Key, Consumer_SECRET,
                 ACCESS_TOKEN, ACCESS_SECRET)

# %%
from twython import Twython

# %%
twitter = Twython(Consumer_Key, Consumer_SECRET,
                 ACCESS_TOKEN, ACCESS_SECRET)

# %%
twitter.search(q='bitcoin', count = '200')
# Out:
# {u'search_metadata': {u'completed_in': 0.088,
#   u'count': 100,
#   u'max_id': 952467370852995072,
#   u'max_id_str': u'952467370852995072',
#   u'query': u'bitcoin',
#   u'refresh_url': u'?since_id=952467370852995072&q=bitcoin&include_entities=1',
#   u'since_id': 0,
#   u'since_id_str': u'0'},
#  u'statuses': [{u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Jan 14 09:08:11 +0000 2018',
#    u'entities': {u'hashtags': [{u'indices': [35, 44], u'text': u'guadagno'},
#      {u'indices': [45, 51], u'text': u'reale'},
#      {u'indices': [52, 57], u'text': u'euro'},
#      {u'indices': [58, 66], u'text': u'dollari'},
#      {u'indices': [67, 71], u'text': u'rtb'},
#      {u'indices': [72, 81], u'text': u'cashflow'},
#      {u'indices': [82, 88], u'text': u'money'},
#      {u'indices': [89, 97], u'text': u'network'},
#      {u'indices': [98, 108], u'text': u'marketing'}],
#     u'symbols': [],
# ...
