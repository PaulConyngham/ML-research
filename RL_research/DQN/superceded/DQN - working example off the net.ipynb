# %% [markdown]
# Based off:
#
# https://keon.io/deep-q-learning/
#
#
# go through tomorrow and print f all the important variables, especially in the replay() function, this is where the magic is happening
#
# looks like this article explains how the loss function works in a deep q network:
#
# https://danieltakeshi.github.io/2016/12/01/going-deeper-into-reinforcement-learning-understanding-dqn/

# %%
# !sudo pip install keras

# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

EPISODES = 1000


class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse',
                      optimizer=Adam(lr=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            targetQ = reward
            if not done:
                
                print np.amax(self.model.predict(next_state)[0])
                
                targetQ = (reward + self.gamma *
                          np.amax(self.model.predict(next_state)[0]))
                
                
            prediction_Q = self.model.predict(state)
            
            print "prediction Q is", prediction_Q
            
            print "prediction Q 0-action is ", prediction_Q[0][action]
            
            prediction_Q[0][action] = targetQ # Dont get this line
            
            self.model.fit(state, prediction_Q, epochs=1, verbose=0)
            
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)


if __name__ == "__main__":
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    agent = DQNAgent(state_size, action_size)
    # agent.load("./save/cartpole-dqn.h5")
    done = False
    batch_size = 32

    for e in range(EPISODES):
        state = env.reset()
        state = np.reshape(state, [1, state_size])
        for time in range(500):
            
            if e > 950:
                env.render()
                
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            reward = reward if not done else -10
            next_state = np.reshape(next_state, [1, state_size])
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            if done:
                print("episode: {}/{}, score: {}, e: {:.2}"
                      .format(e, EPISODES, time, agent.epsilon))
                break
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
        # if e % 10 == 0:
        #     agent.save("./save/cartpole-dqn.h5")
# Out:
# [2018-04-01 10:34:56,808] Making new env: CartPole-v1
# episode: 0/1000, score: 31, e: 1.0
# episode: 1/1000, score: 31, e: 1.0
# -0.004692901
# prediction Q is [[-0.05528791 -0.00889691]]
# prediction Q 0-action is  -0.008896906
# -0.05789077
# prediction Q is [[-0.02489178 -0.04533563]]
# prediction Q 0-action is  -0.024891779
# 0.016772771
# prediction Q is [[-0.05020103 -0.00217164]]
# prediction Q 0-action is  -0.0021716435
# -0.080397025
# prediction Q is [[-0.06874739 -0.05097469]]
# prediction Q 0-action is  -0.068747394
# 0.013228376
# prediction Q is [[-0.08107483  0.04404666]]
# prediction Q 0-action is  -0.081074834
# -0.015643638
# prediction Q is [[0.00808097 0.01443903]]
# prediction Q 0-action is  0.008080972
# 0.028453372
# prediction Q is [[ 0.05298354 -0.05068345]]
# prediction Q 0-action is  -0.050683446
# -0.0072303317
# prediction Q is [[-0.10164212 -0.04430542]]
# prediction Q 0-action is  -0.04430542
# 0.04594641
# prediction Q is [[0.00210438 0.01917467]]
# ...

# %%
# -*- coding: utf-8 -*-
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

EPISODES = 4


class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse',
                      optimizer=Adam(lr=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        
        count = 0
        
        for state, action, reward, next_state, done in minibatch:
            
            targetQ = reward
            
            count += 1
            
            print "training the nn, loop count: ", count

            
            print "targetQ variable before bellman: ", targetQ
            
            test = np.amax(self.model.predict(next_state)[0])
            test_without0 = np.amax(self.model.predict(next_state))
            
            
            
            print "first feed forward pass is: ", test
            print "first feed forward without weird o is: ", test_without0
            print "first feed forward gammarized is: ", test*self.gamma
            
            #ok so what we are doing here is taking the reward (which is always going to be 1.0)
            # and adding it to the gammarized version of which 
            
            if not done:
                                                          
                targetQ = (reward + self.gamma *
                          np.amax(self.model.predict(next_state)[0]))
                
                print "targetQ variable after bellman: ", targetQ
                
            targetQ_f = self.model.predict(state)
            
            print "targetQ_f is: ", targetQ
            
            targetQ_f[0][action] = targetQ
            
            print "targeQt_f0 is: ", targetQ_f[0][action]
            
            self.model.fit(state, targetQ_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)


if __name__ == "__main__":
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    agent = DQNAgent(state_size, action_size)
    # agent.load("./save/cartpole-dqn.h5")
    done = False
    batch_size = 32

    for e in range(EPISODES):
        state = env.reset()
        state = np.reshape(state, [1, state_size])
        
        
        
        for time in range(500):
            
            
            
            if e > 950:
                env.render()
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            reward = reward if not done else -10 # forcing a negative reward.. interesting
            
            next_state = np.reshape(next_state, [1, state_size])
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            if done:
                print("episode: {}/{}, score: {}, e: {:.2}"
                      .format(e, EPISODES, time, agent.epsilon))
                break
        if len(agent.memory) > batch_size:
            
            
            
            
            agent.replay(batch_size)
        # if e % 10 == 0:
        #     agent.save("./save/cartpole-dqn.h5")
